# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5,100)
y = np.sin(x) + x

plt.plot(x,y, label="")

# %%
def fact(n):
    return 1 if n==0 else n*fact(n-1)
print(fact(4))
# Out:
# 24
