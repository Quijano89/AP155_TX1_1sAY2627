# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib.pyplot as plt
from math import pi, sin, sqrt

A = 1
k = (2*pi) / 0.3

r_0 = (-1, 0)
r_1 = (1, 0)

def linspace(start, stop, num):
    step = (stop - start) / (num - 1)
    return [start + i * step for i in range(num)]

x = linspace(-2, 2, 100)
y = linspace(-2, 2, 100)

w = []

for yi in y:
    row = []

    for xi in x:
        r0 = sqrt((xi - r_0[0])**2 + (yi - r_0[1])**2)
        r1 = sqrt((xi - r_1[0])**2 + (yi - r_1[1])**2)

        W = A*sin(k*r0) + A*sin(k*r1)
        row.append(W)

    w.append(row)

plt.imshow(w, extent=[-2, 2, -2, 2], origin="lower")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_breast_cancer

# %%
print('Hello my name is Chino')
# Out:
# Hello my name is Chino

# %%
x = 'chino'

# %%
print(f'My name is', x)
# Out:
# My name is chino

# %%
x1 = 5

# %%
'apple'*x1
# Out:
# 'appleappleappleappleapple'

# %%
cancer = load_breast_cancer()

x2 = cancer.data
y2 = cancer.target

x_train, x_test, y_train, y_test = train_test_split(x2, y2, random_state=0)

model = LinearRegression()
model.fit(x_train, y_train)

print('Train score: {}'.format(model.score(x_train, y_train)))
print('Test score: {}'.format(model.score(x_test, y_test)))
# Out:
# Train score: 0.7824123695930644
# Test score: 0.7291758706114058
