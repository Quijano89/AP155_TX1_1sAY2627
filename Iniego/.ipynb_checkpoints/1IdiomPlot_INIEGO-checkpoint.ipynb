# %% [markdown]
# # AP 155 Lab Exercise
# ---
# ## Exercise 1: Idiomatic Python
#
# _Instructions_:
# - **Report figure (Problem 1):** Plot the 2D wave interference pattern between 2 (or more) coherent sources. Include at least 1 figure.
# - **Report discussion (Problem 2):** Write a custom `matrix_multiply()`function using Python list comprehensions without external libraries (do not use `np.dot()` or `@`).
#     - (i) For larger matrices, which is preferred, the custom `matrix_multiply()` or the `@` operator... why?
#     - (ii) What are the general benefits of writing idiomatic Python?
# - **Code**: Complete the codes and ensure they are functional, error-free, readable, and efficient (where needed). Include a concise markdown documentation highlighting the critical steps of your algorithm for each problem.
#
# ### Student Information
# - _Full Name (Last Name, First Name)_: Iniego, Angel Nicole
# - _Student No._: 2024-09622
# - _Section_: THR-TX-3
#
# ### Grading Information (c/o Lab Instructor)
# - [Rubrics description link](https://drive.google.com/file/d/1G9tPPcyMUag91g_R02O0wsGYPiZWy5Nn/view?usp=drive_link) (Note: percentages may still be tweaked)
#
# | Criteria | Score | Subtotal |
# | --- | --- | --- |
# | Report figure | XX | 20 |
# | Report discussion | XX | 20|
# | Code readability | XX | 20 |
# | Code efficiency | XX | 20 |
# | Code appropriateness  | XX | 20 |
# | **TOTAL** | XXX | 100 |
#
# _Date and Time Scored (MM/DD/YYYY HH:MM AM/PM):_:_

# %% [markdown]
# ---
# ## Section 1: Report

# %% [markdown]
# ### Problem 1 (You may edit this subsection)
#
# <img src="Figures/01_waveplot1.png" alt="WavePlot 1" width=100% caption="Sample Waveplot">
# Figure 1. Combined Plots for Varying Difference Formulas.
#
# <img src="Figures/01_waveplot2.png" alt="WavePlot 2" width=100% caption="Sample Waveplot">
# Figure 2. Combined Plots for Varying Difference Formulas.
# This paper investigates the initialization of common Python libraries.
#
# ### Problem 2
# The problem 2 then explores listcomps which are very much applicable to doing matrix operations. This programs aims to perform matrix multiplication.
#
# ### Other comments
# - EDIT ME
# - A self reflection can be placed here.
# - This portion is not graded.
# - You may insert further questions here.

# %% [markdown]
# ---
# ## Section 2: Code

# %% [markdown]
# ### Problem 1: 2D Wave interference (Gezerlis Problem 1.15)

# %% [markdown]
# Assume that the combined eﬀect of two objects dropped in a water basin can be modelled by:
# $$ W(\textbf{r}) = A \sin (k|\textbf{r}-\textbf{r}_0|) + A  \sin (k|\textbf{r}-\textbf{r}_1|). $$ You can think of this as an updated version of Eq. (1.3) in the book, where we are dealing with the linear addition of sinusoidal waves, instead of electric-field contributions. For simplicity, take $A=1$, $k=2\pi/0.3$, $r_0 = (−1, 0)$ , and $r_1 = (1, 0)$. Since we are now faced with a density plot, you should employ, NOT `streamplot()` but, `imshow()` from `Matplotlib`; in each of $x$ and $y$ your plot should extend from $−4$ to $+4$.

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def wave(r0,r1):
    """
        We define the wave and set parameters to it.
    """
    # We initialize a meshgrid
    x = np.linspace(-4,4,600)
    y = np.linspace(-4,4,600)
    X, Y = np.meshgrid(x,y)
    
    # Defining the wave parameters
    k = 2*np.pi/0.3
    A = 1
    # Setting the source positions
    
    # Distance from the sources
    dist_r0 = np.sqrt((X - r0[0])**2 + (Y - r0[1])**2)
    dist_r1 = np.sqrt((X - r1[0])**2 + (Y - r1[1])**2)

    # Initialize the sum of waves
    W1 = A*np.sin(k*abs(dist_r0))
    W2 = A*np.sin(k*abs(dist_r1))
    resultant = W1 + W2
    
    return resultant

def plottingWaves(resultant):
    """
        Parameter needed is a 1D array. We use this this to plot the waves.
        For more info on parameters, see imshow from matplotlib.
    """
    plt.imshow(resultant, extent=[-4,4,-4,4], origin='lower')
    plt.title("Sample Wave. ")
    plt.xlabel("X Axis")
    plt.ylabel("Y Axis")
    plt.grid(True)
    imageFilePath = "Figures/waveplot1.png"
    plt.savefig(imageFilePath)
    plt.show()
    
# Let us use four points to demonstrate
r0 = (-1,1)
r1 = (1,0)
r2 = (3,2)
r3 = (1,7)
resultant1 = wave(r0,r1)
resultant2 = wave(r2,r3)

# Modify the file name and location as needed
#plottingWaves(resultant1)
plottingWaves(resultant1)

# %% [markdown]
# #### Problem 1 code summary
#
# The program plots the wave interference pattern given two points in the x,y plane. The program demonstrates good programming practices which are defining functions that do one job really well. In this case, the function (1) to define and the function (2) to plot.
#
# ---

# %% [markdown]
# ### Problem 2: Listcomps-maxxing

# %% [markdown]
# Import the `random` library (docs: https://docs.python.org/3/library/random.html). We will be using the `random.randint` function to pick random integers.

# %%
import random
number = random.randint(1, 9)
number
# Out:
# 1

# %% [markdown]
# a. Create a function `random_integer_matrix(nrows, ncols)` that generates a matrix in the form of "list-of-lists" whose elements are random integers from $1$ to $9$. Each "sub-list" inside the main list is a row in the matrix.

# %%
def random_integer_matrix(nrows, ncols):
    """ 
    edit this docstring to explain your function, you may specify input/output
    """
    matrix = []
    for i in range(nrows):
        matrix.append([])
        for j in range(ncols):
            matrix[i].append(random.randint(1,9))
    return [[random.randint(1,9) for i in range(ncols)] for j in range(nrows)]

print(random_integer_matrix(3, 4)) # call the function to create a 3x4 matrix
# Out:
# [[3, 4, 1, 2], [9, 5, 6, 4], [8, 6, 2, 2]]

# %% [markdown]
# b. Create a function `scalar_product(list1, list2)` where you multiply each element at the same index in the two lists and sum/accumulate the results.

# %%
def scalar_product(list1,list2):
    a = 0
    """
    After defining the lists, we then enumerate the elements
    and using the zip to access the elements of the lists.
    """
    for i,j in zip(list1, list2):
        a += i*j
    return a

list1 = (2, 3, 1)
list2 = (1, 2, -1)
print(scalar_product(list1,list2))
# The output should be (2)(1) + (3)(2) + (1)(-1) = 7
# Out:
# 7

# %%
# use as many cell blocks as you want (as long as they all are functional)
# include valuable comments (even for trivial functions, a one-liner will do)

# %% [markdown]
# c. Create a function `transpose_matrix(orig_matrix)` which returns the transpose of any matrix also in "list-of-lists" form. Do not assume the size of the matrix; figure it out within the function. Double-check that your implementations above work. Create a $3\times4$ random integer matrix, print it out and its transpose. The values and shape between the two should be consistent.

# %%
def transpose_matrix(a):
    # Extract the rows and columns of a
    rows = len(a)
    cols = len(a[0])

    # Initialize a matrix with target dimensions based on original matrix
    b = [[0 for x in range(rows)] for x in range(cols)]
    for i in range(rows):
        for j in range(cols):
            b[j][i] = a[i][j]
    return b

a = [[3, 4, 1, 2], [9, 5, 6, 4]]
print(transpose_matrix(a))
# Out:
# [[3, 9], [4, 5], [1, 6], [2, 4]]

# %% [markdown]
# d. Create a function `matrix_multiply(left_matrix, right_matrix)` which performs the matrix multiplication. Do not assume the matrices follow a specific shape. Here's some tips and strategies:
# * Determine how many rows and columns the left and right matrices have. Which numbers should match in order for us to have valid matrix multiplication?
# * Iterating the elements of "list-of-lists" gives us the rows, but we need to iterate the columns for the right matrix.
# * Use the `transpose_matrix` function, then iteratively apply `scalar_product`.

# %%
# Determining the size of the matrix:
    # then if-else for the multiplication
def scalar_product(list1,list2):
    a = 0
    """
    After defining the lists, we then enumerate the elements
    and using the zip to access the elements of the lists.
    """
    for i,j in zip(list1, list2):
        a += i*j
    return a

def transpose_matrix(t):
    """
    Input is t, returns a matrix that is transposed.
    """
    # Extract the rows and columns of a
    rows = len(t)
    cols = len(t[0])

    # Initialize a matrix with target dimensions based on original matrix
    b = [[0 for x in range(rows)] for x in range(cols)]
    for i in range(rows):
        for j in range(cols):
            b[j][i] = t[i][j] # exchange places
    return b
    
def matrix_multiply(left_matrix, right_matrix):
    """
    Multiplies the matrices, given the appropriate size. 
    """
    left_rows = len(left_matrix)
    left_cols = len(left_matrix[0])
    right_rows = len(right_matrix)
    right_cols = len(right_matrix[0])
    
    if right_rows == left_cols:
        right_transposed = transpose_matrix(right_matrix)
        multiplied = []
        for k in range(left_rows):
            multiplied_row = []
            for h in range(right_cols):
                multiplied_row.append(scalar_product(left_matrix[k], right_transposed[h]))
            multiplied.append(multiplied_row)
        return multiplied
    else:
        print("Wrong size.")
    

a = [[3, 4, 1], [9, 5, 6]]
b = [[3, 9], [4, 5], [1, 6]]
matrix_multiply(a,b)
# Out:
# [[26, 53], [53, 142]]

# %% [markdown]
# #### Problem 2 code summary
#
# This programs aims to perform matrix multiplication. It is composed of three major functions, tasked to break down the processes of multiplying matrices which are: (1) scalar product or dot product, (2) transposing a matrix, and (3) a function that brings functions (1) and (2) to perform matrix multiplication.
